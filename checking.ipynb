# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from collections import defaultdict

# %%
train_cliques = pd.read_csv('./input/train_cliques.csv')
train_refeatured = pd.read_csv('./input/train_refeatured.csv')
train_refeatured_2 = pd.read_csv('./input/train_refeatured_2.csv')
X_train = pd.concat((train_cliques, train_refeatured, train_refeatured_2), axis=1)

# %%
X_train.head()
# Out:
#    q1_max  q2_max  q1_min  q2_min  q1_avg  q2_avg  \
# 0       2       2       2       2     2.0     2.0
# 1       2       2       2       2     2.0     2.0
# 2       2       2       2       2     2.0     2.0
# 3       2       2       2       2     2.0     2.0
# 4       2       2       2       2     2.0     2.0
#
#    largest_simultaneously_exist  question1_cliques  question2_cliques  \
# 0                             2                  1                  2
# 1                             2                  8                  3
# 2                             2                  2                  1
# 3                             2                  1                  1
# 4                             2                  3                  1
#
#    larger_cliques_len     ...      wc_diff_unique  wc_ratio_unique  \
# 0                   2     ...                   1         0.916667
# 1                   2     ...                   4         1.500000
# ...

# %%
from sklearn.metrics import roc_auc_score

# %%
train = pd.read_csv('./input/train.csv', encoding="ISO-8859-1")

# %%
index = X_train.axes[1]

# %%
for each in index:
    print(each)
    print(roc_auc_score(train['is_duplicate'],X_train[each]))
# Out:
# q1_max
# 0.789100218234
# q2_max
# 0.781428188643
# q1_min
# 0.716940029561
# q2_min
# 0.717117626094
# q1_avg
# 0.795252693248
# q2_avg
# 0.792872918352
# largest_simultaneously_exist
# 0.801928619629
# question1_cliques
# 0.577371348117
# question2_cliques
# 0.597784421232
# larger_cliques_len
# 0.771350499259
# smaller_cliques_len
# 0.799955187305
# len_q1
# 0.402701821459
# len_q2
# 0.419213127526
# diff_len
# 0.49477937716
# len_char_q1
# 0.415779597934
# len_char_q2
# 0.42469582177
# len_word_q1
# 0.416037928594
# len_word_q2
# 0.420792366041
# common_words
# 0.682904365828
# fuzz_qratio
# 0.729164956738
# fuzz_WRatio
# 0.615479110094
# fuzz_partial_ratio
# 0.721052876232
# fuzz_partial_token_set_ratio
# 0.532061311155
# fuzz_partial_token_sort_ratio
# 0.720642730722
# fuzz_token_set_ratio
# 0.732967208298
# fuzz_token_sort_ratio
# 0.726696677913
# wmd
# 0.291957715521
# norm_wmd
# 0.294554665556
# cosine_distance
# 0.273044472881
# cityblock_distance
# 0.269895680519
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y_train = train['is_duplicate'].values
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=4242)
